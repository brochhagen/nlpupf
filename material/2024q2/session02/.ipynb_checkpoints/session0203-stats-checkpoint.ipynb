# %% [markdown]
# https://githubtocolab.com/brochhagen/nlpupf/blob/main/material/2023q2/session02/session0203-stats.ipynb
#
#
# # Central tendencies
#
# $$\Large \mu_X = \frac{1}{n} \sum_i x_i$$
#
# ***
#
# For finite, odd, and ordered X:
#
# $$\Large \text{median}(X) = x_{\frac{n+1}{2}}$$
#
# For finite, even, and ordered X:
#
#
# $$\Large \text{median}(X) = \frac{x_{n/2} + x_{(n/2)+1}}{2}$$
#
#
# ***
#
# # Variation
#
# $$\Large Var(X) = \frac{1}{n-1} \sum_i(x_i - \bar{x})^{2}$$
#
# ***
#
# $$\Large \sigma_X = \sqrt{\frac{1}{n-1} \sum_i(x_i - \bar{x})^{2}}$$
#
# ***
#
# # (Pearson's) Correlation (coefficient)
#
# $$\Large \rho_{X,Y} = \frac{\text{cov}(X,Y)}{\sigma_X\sigma_Y} = \frac{E[(X - \mu_X)(Y-\mu_Y)]}{\sigma_X\sigma_Y}$$

# %%
X = [1,1,1,21]
Y = [6,8,4]

# %%
from statistics import mean, median,variance,stdev
print(mean(X))
print(mean(Y))
# Out:
# 6
# 6

# %%
print(median(X))
print(median(Y))
# Out:
# 1.0
# 6

# %%
print(variance(X))
print(variance(Y))
# Out:
# 100
# 4

# %%
print(stdev(X))
print(stdev(Y))
# Out:
# 10.0
# 2.0

# %% [markdown]
# # Simulation to illustrate

# %%
#Enabling R magic
# %load_ext rpy2.ipython

# %%
# %%R
#
# set.seed(123)
#
# X <- round(
#         rnorm(mean = 65,
#               sd   = 10,
#               n    = 100),
#         0)
#
# print(X[1:5])
# Out:
# [1] 59 63 81 66 66

# %%
# %%R
# set.seed(5)
#
# sigma_err <- rnorm(mean = 0, sd = 5, n = 100)
# Y = round(2.5 * X + sigma_err,0)
#
# print(Y[1:5])
# Out:
# [1] 143 164 196 165 174

# %%
# %%R
# plot(X,Y)

# %%
# %%R
# cor(X,Y)
# Out:
# [1] 0.9792165
